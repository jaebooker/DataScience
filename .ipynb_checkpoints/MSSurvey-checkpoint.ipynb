# %%
# Pandas is a library for basic data analysis
import pandas as pd

# NumPy is a library for advanced mathematical computation
import numpy as np

# MatPlotLib is a library for basic data visualization
import matplotlib.pyplot as plt

# SeaBorn is a library for advanced data visualization
import seaborn as sns

# %%
sns.set(style="white", context="notebook", palette="deep")

COLOR_COLUMNS = ["#66C2FF", "#5CD6D6", "#00CC99", "#85E085", "#FFD966", "#FFB366", "#FFB3B3", "#DAB3FF", "#C2C2D6"]

sns.set_palette(palette=COLOR_COLUMNS, n_colors=4)

# %%
FILEPATH = "Notebooks/Datasets/MakeSchoolData/SA_Feedback_Surveys_FINAL/2017/Student_Feedback_Surveys_Superview.csv"

df = pd.read_csv(FILEPATH)

# %%
df
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
df.iloc[0]
# Out:
# ID                            134
# Location            San Francisco
# Track              Apps, Explorer
# Week                       Week 1
# Rating (Num)                    3
# Schedule Pacing        Just right
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# ID                                36
# Location                 Los Angeles
# Track                           Apps
# Week                          Week 1
# Rating (Num)                       4
# Schedule Pacing    A little too fast
# Name: 1, dtype: object

# %%
df.iloc[3]
# Out:
# ID                               253
# Location                         NaN
# Track                            NaN
# Week                          Week 2
# Rating (Num)                       4
# Schedule Pacing    A little too fast
# Name: 3, dtype: object

# %%
df.iloc[2]
# Out:
# ID                           117
# Location           San Francisco
# Track                      Games
# Week                      Week 1
# Rating (Num)                   4
# Schedule Pacing     Way too slow
# Name: 2, dtype: object

# %%
df['Rating (Num)']
# Out:
# 0        3
# 1        4
# 2        4
# 3        4
# 4        4
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5
# 11       5
# 12       5
# 13       5
# 14       5
# 15       5
# 16       5
# 17       5
# 18       5
# 19       5
# 20       6
# 21       6
# 22       6
# 23       6
# 24       6
# 25       6
# 26       6
# 27       6
# 28       6
# 29       6
#         ..
# 1423    10
# 1424     8
# 1425     9
# 1426    10
# 1427     9
# 1428     9
# 1429     8
# 1430    10
# 1431    10
# 1432     9
# 1433     9
# 1434    10
# 1435     8
# 1436     7
# 1437     7
# 1438     7
# 1439     9
# 1440     8
# 1441     7
# 1442    10
# 1443    10
# 1444     9
# 1445     9
# 1446     3
# 1447    10
# 1448    10
# 1449     8
# 1450    10
# 1451     1
# 1452     8
# Name: Rating (Num), Length: 1453, dtype: object

# %%
df[df['Rating (Num)']=="10"]
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 376     12        Atlanta             Apps  Week 1           10
# 377     13        Atlanta   Apps, Explorer  Week 1           10
# 378     17   Redwood City             Apps  Week 1           10
# 379     19   Redwood City             Apps  Week 1           10
# 380     22   Redwood City             Apps  Week 1           10
# 381     24   Redwood City             Apps  Week 1           10
# 382     34    Los Angeles             Apps  Week 1           10
# 383     42        Chicago             Apps  Week 1           10
# 384     43        Chicago   Apps, Explorer  Week 1           10
# 385     44        Chicago             Apps  Week 1           10
# 386     49  San Francisco               VR  Week 1           10
# 387     50  San Francisco               VR  Week 1           10
# 388     51  San Francisco               VR  Week 1           10
# 389     52  San Francisco               VR  Week 1           10
# ...

# %%
df[df['Rating (Num)']=="9"]
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 256     11        Atlanta   Apps, Explorer  Week 1            9
# 257     15   Redwood City             Apps  Week 1            9
# 258     27    Los Angeles            Games  Week 1            9
# 259     30    Los Angeles             Apps  Week 1            9
# 260     32    Los Angeles             Apps  Week 1            9
# 261     33    Los Angeles            Games  Week 1            9
# 262     56  San Francisco               VR  Week 1            9
# 263     59  San Francisco             Apps  Week 1            9
# 264     60  San Francisco             Apps  Week 1            9
# 265     68  San Francisco             Apps  Week 1            9
# 266     69  San Francisco             Apps  Week 1            9
# 267     73  San Francisco             Apps  Week 1            9
# 268     79    Santa Clara  Games, Explorer  Week 1            9
# 269     82    Santa Clara             Apps  Week 1            9
# ...

# %%
promoter = df[df['Rating (Num)']=="9"]

# %%
promoter
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 256     11        Atlanta   Apps, Explorer  Week 1            9
# 257     15   Redwood City             Apps  Week 1            9
# 258     27    Los Angeles            Games  Week 1            9
# 259     30    Los Angeles             Apps  Week 1            9
# 260     32    Los Angeles             Apps  Week 1            9
# 261     33    Los Angeles            Games  Week 1            9
# 262     56  San Francisco               VR  Week 1            9
# 263     59  San Francisco             Apps  Week 1            9
# 264     60  San Francisco             Apps  Week 1            9
# 265     68  San Francisco             Apps  Week 1            9
# 266     69  San Francisco             Apps  Week 1            9
# 267     73  San Francisco             Apps  Week 1            9
# 268     79    Santa Clara  Games, Explorer  Week 1            9
# 269     82    Santa Clara             Apps  Week 1            9
# ...

# %%
promoter = df[df['Rating (Num)']=="9"]

# %%
promoter
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 256     11        Atlanta   Apps, Explorer  Week 1            9
# 257     15   Redwood City             Apps  Week 1            9
# 258     27    Los Angeles            Games  Week 1            9
# 259     30    Los Angeles             Apps  Week 1            9
# 260     32    Los Angeles             Apps  Week 1            9
# 261     33    Los Angeles            Games  Week 1            9
# 262     56  San Francisco               VR  Week 1            9
# 263     59  San Francisco             Apps  Week 1            9
# 264     60  San Francisco             Apps  Week 1            9
# 265     68  San Francisco             Apps  Week 1            9
# 266     69  San Francisco             Apps  Week 1            9
# 267     73  San Francisco             Apps  Week 1            9
# 268     79    Santa Clara  Games, Explorer  Week 1            9
# 269     82    Santa Clara             Apps  Week 1            9
# ...

# %%
promoter10 = df[df['Rating (Num)']=="10"]

# %%
promoter10
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 376     12        Atlanta             Apps  Week 1           10
# 377     13        Atlanta   Apps, Explorer  Week 1           10
# 378     17   Redwood City             Apps  Week 1           10
# 379     19   Redwood City             Apps  Week 1           10
# 380     22   Redwood City             Apps  Week 1           10
# 381     24   Redwood City             Apps  Week 1           10
# 382     34    Los Angeles             Apps  Week 1           10
# 383     42        Chicago             Apps  Week 1           10
# 384     43        Chicago   Apps, Explorer  Week 1           10
# 385     44        Chicago             Apps  Week 1           10
# 386     49  San Francisco               VR  Week 1           10
# 387     50  San Francisco               VR  Week 1           10
# 388     51  San Francisco               VR  Week 1           10
# 389     52  San Francisco               VR  Week 1           10
# ...

# %%
passive = df[df['Rating (Num)']=="8"]

# %%
passive7 = df[df['Rating (Num)']=="7"]

# %%
passive7
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 44      20   Redwood City             Apps  Week 1            7
# 45      26    Los Angeles             Apps  Week 1            7
# 46      35    Los Angeles             Apps  Week 1            7
# 47      38        Chicago             Apps  Week 1            7
# 48      48  San Francisco               VR  Week 1            7
# 49      62  San Francisco             Apps  Week 1            7
# 50      67  San Francisco             Apps  Week 1            7
# 51      72  San Francisco             Apps  Week 1            7
# 52      75  San Francisco             Apps  Week 1            7
# 53      85    Santa Clara             Apps  Week 1            7
# 54      87  San Francisco             Apps  Week 1            7
# 55     104  San Francisco   Apps, Explorer  Week 1            7
# 56     107  San Francisco            Games  Week 1            7
# 57     118  San Francisco   Apps, Explorer  Week 1            7
# ...

# %%
promoters = len(promoter) + len(promoter10)

# %%
passives = len(passive) + len(passive7)

# %%
detractors = len(df) - (promoters + passives)

# %%
promoters
# Out:
# 760

# %%
passives
# Out:
# 569

# %%
detractors
# Out:
# 124

# %%
len(df)
# Out:
# 1453

# %%
detractors+passives+promoters
# Out:
# 1453

# %%
NPS = (promoters - detractors) / (promoters + passives + detractors)

# %%
NPS
# Out:
# 0.4377150722642808

# %%
promoters-detractors
# Out:
# 636

# %%
len(df)
# Out:
# 1453

# %%
636/1453
# Out:
# 0.4377150722642808

# %%
NPS = ((promoters - detractors) / (len(df))) * 100

# %%
NPS
# Out:
# 43.77150722642808

# %%
promoters/len(df)
# Out:
# 0.5230557467309016

# %%
passives/len(df)
# Out:
# 0.39160357880247765

# %%
detractors/len(df)
# Out:
# 0.08534067446662079

# %%
(promoters+passives)/len(df)
# Out:
# 0.9146593255333793

# %%
num5 = df[df['Rating (Num)']=="5"]

# %%
num6 = df[df['Rating (Num)']=="6"]

# %%
positives = len(num6) + passives + promoters

# %%
positives
# Out:
# 1388

# %%
positives/len(df)
# Out:
# 0.9552649690295939

# %%
negatives = detractors - len(num5)

# %%
negatives
# Out:
# 89

# %%
negatives/len(df)
# Out:
# 0.06125258086717137

# %%
import glob

# %%
mdf = glob.glob('../../SA_Feedback_Surveys_FINAL/2016/*.csv')

# %%
mdf
# Out:
# []

# %%
mmdf = pd.read_csv(mdf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-e274fa65207d> in <module>()
# ----> 1 mmdf = pd.read_csv(mdf)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
def funky():
    ds = list()
    for i in mdf:
        ds.append(pd.read_csv(i))
    return ds

# %%
ds = funky()

# %%
rating = 'How would you rate your overall satisfaction with the Summer Academy this week?'

# %%
ds4[ds4[rating]==4]

# %%
pro = 0

# %%
len4 = len(ds4[ds4[rating]==4])

# %%
prom = 0

# %%
for i in range(0,len(ds)-1):
    if i != 18:
        pro += len(ds[i][ds[i][rating]==4])
        pro += len(ds[i][ds[i][rating]==5])

# %%
neg = 0

# %%
proactives = pro/len(ds)

# %%
proactives

# %%
for i in range(0,len(ds)-1):
    if i != 18:
        neg += len(ds[i][ds[i][rating]==1])
        neg += len(ds[i][ds[i][rating]==2])

# %%
negaverse = neg/len(ds)

# %%
negaverse

# %%
med = 0

# %%
for i in range(0,len(ds)-1):
    if i != 18:
        med += len(ds[i][ds[i][rating]==3])

# %%
med

# %%
normies = med/len(ds)

# %%
normies

# %%
proactives-normies

# %%
import matplotlib.pyplot as plt

# %%
df[(df["Rating (Num)"] == "10")].Week.hist(bins = 16)
df[(df["Rating (Num)"] == "9")].Week.hist(bins = 16)

# %%
import matplotlib.pyplot as plt

# %%
df.plot.scatter(x="Rating (Num)",y="Week")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-6998810f8bfe> in <module>()
# ----> 1 df.plot.scatter(x=int("Rating (Num)"),y="Week")
#
# ValueError: invalid literal for int() with base 10: 'Rating (Num)'

# %%
df[df['Rating (Num)'] == '10'].groupby('Week')['Track'].hist(bins=16)
# Out:
# Week
# Week 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Week 2    AxesSubplot(0.125,0.125;0.775x0.755)
# Week 3    AxesSubplot(0.125,0.125;0.775x0.755)
# Week 4    AxesSubplot(0.125,0.125;0.775x0.755)
# Week 5    AxesSubplot(0.125,0.125;0.775x0.755)
# Week 6    AxesSubplot(0.125,0.125;0.775x0.755)
# Week 7    AxesSubplot(0.125,0.125;0.775x0.755)
# Week 8    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Track, dtype: object

# %%
df[df['Rating (Num)'] == '10'].groupby('Schedule Pacing')['Week'].hist(bins=16)
# Out:
# Schedule Pacing
# A little too fast    AxesSubplot(0.125,0.125;0.775x0.755)
# A little too slow    AxesSubplot(0.125,0.125;0.775x0.755)
# Just right           AxesSubplot(0.125,0.125;0.775x0.755)
# Way too fast         AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Week, dtype: object

# %%
df[df['Rating (Num)'] == '10'].Week.hist(bins = 16)

# %%
df[df['Rating (Num)'] == ''].Age.plot(kind = 'kde')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-2aba39be3641> in <module>()
# ----> 1 df[df['Rating (Num)'] == '10'].Week.plot(kind = 'kde')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
df[df['Rating (Num)'] == '10'].Track.hist(bins = 16)

# %%
# Out:
#   File "<ipython-input-79-86790e886343>", line 1
#     df[df['Rating (Num)'] == '10']."Schedule Pacing".hist(bins = 16)
#                                                    ^
# SyntaxError: invalid syntax

# %%
df[df['Schedule Pacing'] == 'Just right'].Week.hist(bins = 16)

# %%
df[df['Schedule Pacing'] == 'Way too fast'].Week.hist(bins = 16)

# %%
df[df['Schedule Pacing'] == 'Way too slow'].Week.hist(bins = 16)

# %%
df[df['Schedule Pacing'] == 'A little too fast'].Week.hist(bins = 16)

# %%
df[df['Schedule Pacing'] == 'A little too slow'].Week.hist(bins = 16)
