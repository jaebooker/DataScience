# %%
# Pandas is a library for basic data analysis
import pandas as pd

# NumPy is a library for advanced mathematical computation
import numpy as np

# MatPlotLib is a library for basic data visualization
import matplotlib.pyplot as plt

# SeaBorn is a library for advanced data visualization
import seaborn as sns

# %%
sns.set(style="white", context="notebook", palette="deep")

COLOR_COLUMNS = ["#66C2FF", "#5CD6D6", "#00CC99", "#85E085", "#FFD966", "#FFB366", "#FFB3B3", "#DAB3FF", "#C2C2D6"]

sns.set_palette(palette=COLOR_COLUMNS, n_colors=4)

# %%
FILEPATH = "Notebooks/Datasets/titanic.csv"

df = pd.read_csv(FILEPATH)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df[(df['Survived']) == 0 & (df['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 24            25         0       3
# 26            27         0       3
# 27            28         0       1
# 29            30         0       3
# 30            31         0       1
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 37            38         0       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# 42            43         0       3
# 45            46         0       3
# ...

# %%
import matplotlib.pyplot as plt

# %%
df[(df["Sex"] == "female")].Age.hist(bins = 16)
df[(df["Sex"] == "male")].Age.hist(bins = 16)

# %%
df[(df["Sex"] == "male") & (df['Survived'] == 1)].Age.hist(bins = 16)

# %%
df[(df["Sex"] == "male") & (df['Survived'] == 0)].Age.hist(bins = 16)

# %%
df[(df["Sex"] == "female") & (df['Survived'] == 0)].Age.hist(bins = 16)

# %%
df[(df["Sex"] == "female") & (df['Survived'] == 1)].Age.hist(bins = 16)

# %%
df['Gender'] = df["Sex"].map( { "female": 0, "male": 1 } )

# %%
df['Gender'] = df["Sex"].map( { "female": 0, "male": 1 } ).astype(int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
df['Gender2'] = df['Sex'].apply(lambda sex: "1" if sex == "male" else "0")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender Gender2
# 0      0         A/5 21171   7.2500   NaN        S       1       1
# 1      0          PC 17599  71.2833   C85        C       0       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0       0
# ...

# %%
def numeric_gender(sex):
    if sex == 'female':
        return 0
    if sex == 'male':
        return 1

df["Gender"] = df["Sex"].apply(numeric_gender)
df[["Sex", "Gender"]]
# Out:
#         Sex  Gender
# 0      male       1
# 1    female       0
# 2    female       0
# 3    female       0
# 4      male       1
# 5      male       1
# 6      male       1
# 7      male       1
# 8    female       0
# 9    female       0
# 10   female       0
# 11   female       0
# 12     male       1
# 13     male       1
# 14   female       0
# 15   female       0
# 16     male       1
# 17     male       1
# 18   female       0
# 19   female       0
# 20     male       1
# 21     male       1
# 22   female       0
# 23     male       1
# 24   female       0
# 25   female       0
# 26     male       1
# 27     male       1
# 28   female       0
# 29     male       1
# ..      ...     ...
# 861    male       1
# 862  female       0
# 863  female       0
# 864    male       1
# 865  female       0
# 866  female       0
# 867    male       1
# 868    male       1
# 869    male       1
# 870    male       1
# 871  female       0
# 872    male       1
# 873    male       1
# ...

# %%
df = df.drop(['Gender2'], axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
df.shape
# Out:
# (891, 13)

# %%
df['Age'].plot.box()

# %%
df['Gender'].plot.box()

# %%
df['Age'].plot.box()

# %%
df[df['Embarked'] == 'C'].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 9            10         1       2
# 19           20         1       3
# 26           27         0       3
# 30           31         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Gender
# 1       0  PC 17599  71.2833   C85        C       0
# 9       0    237736  30.0708   NaN        C       0
# 19      0      2649   7.2250   NaN        C       0
# 26      0      2631   7.2250   NaN        C       1
# ...

# %%
c = df[df['Embarked'] == 'C']

# %%
c['Age'].plot.box()

# %%
df[df['Embarked'] == 'C'].Age.hist(bins = 16)

# %%
df[df['Embarked'] == 'C'].Age.plot(kind = 'kde')lkq

# %%
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
df['Age'].nunique()
# Out:
# 88

# %%
df['Sex'].nunique()
# Out:
# 2

# %%
df['Survived'].nunique()
# Out:
# 2

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Embarked'].value_counts().plot(kind='bar')

# %%
df['Embarked'].value_counts().plot(kind='bar').invert_yaxis()

# %%
df['Embarked'].value_counts().plot(kind='barh').invert_yaxis()

# %%
sns.countplot(x="Embarked",palette="winter",data=df)

# %%
sns.countplot(x="Embarked",palette="autumn",data=df)

# %%
sns.countplot(x="Embarked",palette="summer",data=df)

# %%
sns.countplot(x="Embarked",palette="spring",data=df)

# %%
sns.countplot(x="Embarked",palette="winter_r",data=df)

# %%
sns.countplot(x="Embarked",palette="cubehelix_r",data=df)

# %%
sns.countplot(x="Embarked",palette="spring_r",data=df)

# %%
df['Sex'].value_counts().plot(kind='bar')

# %%
sns.countplot(x="Embarked",palette="spring_r",data=df)

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].hist(bins=16)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[df['Survived'] == 0].groupby('Sex')['Age'].hist(bins=16)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[(df['Embarked'] == 'C')].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   168.000000  168.000000  168.000000  130.000000  168.000000
# mean    445.357143    0.553571    1.886905   30.814769    0.386905
# std     259.454201    0.498608    0.944100   15.434860    0.557213
# min       2.000000    0.000000    1.000000    0.420000    0.000000
# 25%     235.500000    0.000000    1.000000   21.250000    0.000000
# 50%     455.000000    1.000000    1.000000   29.000000    0.000000
# 75%     651.000000    1.000000    3.000000   40.000000    1.000000
# max     890.000000    1.000000    3.000000   71.000000    2.000000
#
#             Parch        Fare      Gender
# count  168.000000  168.000000  168.000000
# mean     0.363095   59.954144    0.565476
# std      0.660481   83.912994    0.497176
# min      0.000000    4.012500    0.000000
# 25%      0.000000   13.697950    0.000000
# 50%      0.000000   29.700000    1.000000
# 75%      1.000000   78.500025    1.000000
# ...

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].agg(np.mean)
# Out:
# Sex
# female    28.344262
# male      32.998841
# Name: Age, dtype: float64

# %%
import seaborn as sns

# %%
sns.regplot(x="Age",y="Age",fit_reg=False,data=df)

# %%
df.plot.scatter(x="Age",y="Fare")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import matplotlib.pyplot as plt

# %%
df.plot.scatter(x="Age", y="Fare")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.barplot(x="Sex",y="Survived",hue="Pclass",data=df)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x="Age",y="Survived",hue="Pclass",data=df)

# %%
sns.countplot(x="Sex",hue="Pclass",data=df)

# %%
df["Pclass"].max()/100
# Out:
# 0.03

# %%
df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]['Survived'].value_counts()
# Out:
# 1    91
# 0     3
# Name: Survived, dtype: int64

# %%
df[(df['Sex'] == 'male') & (df['Pclass'] == 3)]['Survived'].value_counts()
# Out:
# 0    300
# 1     47
# Name: Survived, dtype: int64

# %%
df[(df['Sex'] == 'female') & (df['Pclass'] == 3)]['Survived'].value_counts()
# Out:
# 1    72
# 0    72
# Name: Survived, dtype: int64

# %%
df[(df['Sex'] == 'male') & (df['Pclass'] == 1)]['Survived'].value_counts()
# Out:
# 0    77
# 1    45
# Name: Survived, dtype: int64

# %%
df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]['Survived'].value_counts()/100
# Out:
# 1    0.91
# 0    0.03
# Name: Survived, dtype: float64

# %%
df.groupby(['Sex'])['Pclass'].value_counts().unstack().plot(kind="bar",stacked=True)

# %%
df.groupby(['Sex'])['Pclass'].value_counts().plot(kind="bar",stacked=True)

# %%
df.groupby(['Sex'])['Pclass'].value_counts().unstack().plot(kind="bar",stacked=True)

# %%
sns.countplot(x="Pclass", hue="Sex", data=df[df["Sex"] == "male"], palette="winter", alpha=1)
sns.countplot(x="Pclass", hue="Sex", data=df[df["Sex"] == "female"], palette="spring", alpha=1)

# %%
pd.crosstab(df['Sex'],df['Pclass']).plot(kind="bar",stacked=True)

# %%
sns.heatmap(pd.crosstab(df['Sex'],df['Embarked'],normalize='index'),cmap="YlGnBu", annot=True)

# %%
adf = pd.DataFrame(data={'x1': ['A', 'B', 'C'], 'x2' : [1, 2, 3]})

# %%
ls_fare = df['Fare'].dropna().values

# %%
import matplotlib.pyplot as plt

# %%
df['Fare'].hist(bins=10)
plt.show()

# %%
cheap_fares = [i for i in ls_fare if i < np.mean(ls_fare)]

# %%
len(cheap_fares) / len(ls_fare)
# Out:
# 0.7631874298540965

# %%
p = df[(df['Fare']>100) & (df['Survived'] == 1)]

# %%
len(p)
# Out:
# 39

# %%
len(df[df['Fare']>100])
# Out:
# 53

# %%
39/53
# Out:
# 0.7358490566037735

# %%
p = df[(df['Survived']==1) & (df['Gender'] == 1)]

# %%
len(p)
# Out:
# 109

# %%
p = df[(df['Survived']==1)]

# %%
len(p)
# Out:
# 342

# %%
109/342
# Out:
# 0.31871345029239767

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
lsage = df['Age'].dropna().values

# %%
sns.distplot(df['Age'].dropna(), hist=True,kde=True,bins=20)

# %%
cdf = sns.distplot(df['Age'].dropna(), hist_kws=dict(cumulative=True),kde_kws=dict(cumulative=True))

# %%
import scipy.stats as st

# %%
print(st.norm.cdf(1)-st.norm.cdf(-1))
# Out:
# 0.6826894921370859

# %%
print(st.norm.cdf(1))
# Out:
# 0.8413447460685429

# %%
print(st.norm.cdf(-1))
# Out:
# 0.15865525393145707

# %%
print(st.norm.pdf(1))
# Out:
# 0.24197072451914337

# %%
print(st.norm.pdf(-3))
# Out:
# 0.0044318484119380075
